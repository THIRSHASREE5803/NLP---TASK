# %%
import nltk

# %%
#1.frequency distribution function word in text
text='Up to the 1980s, most natural language processing systems were based on complex sets of hand-written rules. Starting in the late 1980s, however, there was a revolution in natural language processing with the introduction of machine learning algorithms for language processing.'
fd=nltk.FreqDist(text.split())
fd
# Out:
# FreqDist({'the': 3, 'language': 3, '1980s,': 2, 'natural': 2, 'processing': 2, 'of': 2, 'in': 2, 'Up': 1, 'to': 1, 'most': 1, ...})

# %%
#2.conditional distribution 
from nltk.probability import ConditionalFreqDist

# %%
cfd=ConditionalFreqDist((len(word),word) for word in text.split())

# %%
cfd[4]
# Out:
# FreqDist({'most': 1, 'were': 1, 'sets': 1, 'late': 1, 'with': 1})

# %%
#chinese segmentation using jieba
# !pip install jieba
# Out:
# Requirement already satisfied: jieba in c:\python311\lib\site-packages (0.42.1)

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (22.2.2)
# Collecting pip
#   Using cached pip-22.3.1-py3-none-any.whl (2.1 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 22.2.2
#     Uninstalling pip-22.2.2:
#       Successfully uninstalled pip-22.2.2
# Successfully installed pip-22.3.1
# Note: you may need to restart the kernel to use updated packages.

# %%
#chinese segmentation using jieba
# !pip install jieba
# Out:
# Requirement already satisfied: jieba in c:\python311\lib\site-packages (0.42.1)

# %%
import jieba

# %%
seg=jieba.cut("網站有中、英文版本，也有繁、簡體版，可通過每頁左上角的連結隨時調整",cut_all=True)

# %%
seg
# Out:
# <generator object Tokenizer.cut at 0x000001A7A6250E40>

# %%
print(" ".join(seg))
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\ADMIN\AppData\Local\Temp\jieba.cache
# Loading model cost 0.670 seconds.
# Prefix dict has been built successfully.
# 網 站 有 中 、 英文 英文版 文版 版本 ， 也 有 繁 、 簡 體 版 ， 可 通 過 每 頁 左上 左上角 上角 的 連 結 隨 時 調 整

# %%
#4
import nltk
sent="Become an Expert in NLP"
words=nltk.word_tokenize(sent)
print(words)
# Out:
# ['Become', 'an', 'Expert', 'in', 'NLP']

# %%
import nltk

# %%
#5
texts="APJ Abdul Kalam was unique man. The most remarkable aspect of this man was his leaping optimism, positive attitude even amidst frustrating circumstances. While addressing the ISRO scientists in Trivandrum he showed remarkable positivity in science, politics and journalism and everything he touched upon and looked forward to India planting the tricolor on the moon when PSLV faced some failures! At the INS meeting at Kalpakkam in 2003, he overruled Chairman AEC and suggested a much higher target for the projected nuclear power in India. His impatience to find applications of his research in other fields resulted in the development of a metallurgical alloy for designing artificial limbs which was 1/10th weight of the normal ones and using his innovation to design a cheaper coronary stent."
for text in texts:
    sentences=nltk.sent_tokenize(text)
    for sentence in sentences:
        word=nltk.word_tokenize(sentence)
        print(word)
        tagged=nltk.pos_tag(words)
        print(tagged)
# Out:
# ['A']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['P']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['J']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['A']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['b']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['d']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['u']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['l']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['K']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['l']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['m']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['w']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['s']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['u']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['q']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['u']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['m']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['.']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['T']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['h']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['m']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['o']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['s']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['r']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['m']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['r']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['k']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['b']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['l']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['s']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['p']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['c']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['o']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['f']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['h']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['s']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['m']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['w']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['s']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['h']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['s']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['l']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['p']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['g']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['o']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['p']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['m']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['s']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['m']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# [',']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['p']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['o']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['s']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['v']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['u']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['d']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['v']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['m']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['d']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['s']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['f']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['r']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['u']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['s']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['r']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['g']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['c']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['r']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['c']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['u']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['m']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['s']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['c']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['s']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['.']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['W']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['h']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['l']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['d']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['d']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['r']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['s']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['s']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['g']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['h']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['I']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['S']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['R']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['O']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['s']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['c']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['s']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['s']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['T']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['r']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['v']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['d']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['r']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['u']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['m']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['h']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['s']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['h']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['o']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['w']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['d']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['r']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['m']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['r']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['k']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['b']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['l']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['p']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['o']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['s']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['v']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['y']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['s']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['c']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['c']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# [',']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['p']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['o']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['l']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['c']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['s']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['d']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['j']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['o']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['u']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['r']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['l']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['s']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['m']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['d']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['v']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['r']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['y']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['h']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['g']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['h']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['o']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['u']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['c']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['h']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['d']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['u']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['p']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['o']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['d']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['l']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['o']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['o']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['k']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['d']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['f']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['o']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['r']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['w']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['r']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['d']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['o']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['I']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['d']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['p']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['l']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['g']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['h']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['r']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['c']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['o']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['l']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['o']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['r']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['o']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['h']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['m']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['o']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['o']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['w']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['h']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['P']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['S']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['L']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['V']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['f']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['c']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['d']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['s']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['o']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['m']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['f']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['l']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['u']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['r']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['s']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['!']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['A']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['h']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['I']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['N']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['S']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['m']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['g']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['K']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['l']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['p']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['k']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['k']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['m']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['2']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['0']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['0']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['3']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# [',']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['h']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['o']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['v']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['r']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['r']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['u']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['l']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['d']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['C']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['h']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['r']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['m']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['A']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['E']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['C']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['d']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['s']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['u']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['g']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['g']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['s']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['d']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['m']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['u']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['c']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['h']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['h']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['g']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['h']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['r']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['r']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['g']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['f']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['o']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['r']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['h']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['p']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['r']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['o']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['j']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['c']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['d']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['u']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['c']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['l']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['r']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['p']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['o']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['w']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['r']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['I']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['d']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['.']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['H']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['s']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['m']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['p']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['c']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['o']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['f']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['d']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['p']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['p']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['l']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['c']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['o']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['s']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['o']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['f']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['h']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['s']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['r']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['s']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['r']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['c']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['h']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['o']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['h']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['r']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['f']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['l']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['d']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['s']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['r']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['s']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['u']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['l']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['d']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['h']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['d']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['v']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['l']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['o']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['p']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['m']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['o']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['f']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['m']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['l']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['l']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['u']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['r']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['g']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['c']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['l']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['l']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['l']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['o']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['y']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['f']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['o']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['r']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['d']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['s']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['g']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['g']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['r']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['f']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['c']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['l']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['l']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['m']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['b']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['s']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['w']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['h']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['c']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['h']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['w']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['s']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['1']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['/']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['1']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['0']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['h']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['w']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['g']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['h']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['o']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['f']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['h']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['o']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['r']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['m']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['l']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['o']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['s']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['d']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['u']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['s']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['g']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['h']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['s']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['o']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['v']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['o']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['o']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['d']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['s']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['i']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['g']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['c']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['h']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['p']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['r']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['c']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['o']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['r']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['o']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['a']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['r']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['y']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['s']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['e']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['n']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['t']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
# ['.']
# [('Become', 'NNP'), ('an', 'DT'), ('Expert', 'NNP'), ('in', 'IN'), ('NLP', 'NNP')]
